# %%
from torchsummary import summary
from src import NuClick, UNet

# %%
summary(UNet(), (3, 512, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 512, 512]           1,792
#        BatchNorm2d-2         [-1, 64, 512, 512]             128
#               ReLU-3         [-1, 64, 512, 512]               0
#             Conv2d-4         [-1, 64, 512, 512]          36,928
#        BatchNorm2d-5         [-1, 64, 512, 512]             128
#               ReLU-6         [-1, 64, 512, 512]               0
#          MaxPool2d-7         [-1, 64, 256, 256]               0
#             Conv2d-8        [-1, 128, 256, 256]          73,856
#        BatchNorm2d-9        [-1, 128, 256, 256]             256
#              ReLU-10        [-1, 128, 256, 256]               0
#            Conv2d-11        [-1, 128, 256, 256]         147,584
#       BatchNorm2d-12        [-1, 128, 256, 256]             256
#              ReLU-13        [-1, 128, 256, 256]               0
# ...

# %%
summary(NuClick(), (5, 512, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 512, 512]          15,744
#        BatchNorm2d-2         [-1, 64, 512, 512]             128
#               ReLU-3         [-1, 64, 512, 512]               0
#             Conv2d-4         [-1, 32, 512, 512]          51,232
#        BatchNorm2d-5         [-1, 32, 512, 512]              64
#               ReLU-6         [-1, 32, 512, 512]               0
#             Conv2d-7         [-1, 32, 512, 512]           9,248
#        BatchNorm2d-8         [-1, 32, 512, 512]              64
#               ReLU-9         [-1, 32, 512, 512]               0
#         MaxPool2d-10         [-1, 32, 256, 256]               0
#            Conv2d-11         [-1, 64, 256, 256]          18,496
#       BatchNorm2d-12         [-1, 64, 256, 256]             128
#              ReLU-13         [-1, 64, 256, 256]               0
# ...
